# %%
import numpy as np
import pandas as pd
import sklearn as sk

import os

# %%
data_path = '../data/'

# %%
# cohort_path =

# %%
cohort_df = pd.read_csv(os.path.join(data_path, 'cohort.csv'), 
                        parse_dates = ['intime', 
                                       'outtime', 
                                       'suspected_infection_time_poe', 
                                       'window_start', 
                                       'window_end'], 
                        infer_datetime_format= True,
                        skipfooter = 1)
# Out:
# /Users/stephenpfohl/miniconda3/lib/python3.6/site-packages/ipykernel/__main__.py:9: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.

# %%
cohort_df.apply(lambda x: type(x.values[1]))
# Out:
# subject_id                                               <class 'int'>
# hadm_id                                                  <class 'int'>
# icustay_id                                               <class 'int'>
# intime                          <class 'pandas._libs.tslib.Timestamp'>
# outtime                         <class 'pandas._libs.tslib.Timestamp'>
# suspected_infection_time_poe    <class 'pandas._libs.tslib.Timestamp'>
# window_start                    <class 'pandas._libs.tslib.Timestamp'>
# window_end                      <class 'pandas._libs.tslib.Timestamp'>
# hospital_expire_flag                                     <class 'int'>
# dtype: object

# %%
temp_start = cohort_df['window_start'].values[1]
temp_end = cohort_df['window_end'].values[1]

# %%
temp_end
# Out:
# numpy.datetime64('2135-10-29T06:28:00.000000000')

# %%
pd.date_range(start = temp_start, end = temp_end, freq = '4H')
# Out:
# DatetimeIndex(['2135-10-26 06:28:00', '2135-10-26 10:28:00',
#                '2135-10-26 14:28:00', '2135-10-26 18:28:00',
#                '2135-10-26 22:28:00', '2135-10-27 02:28:00',
#                '2135-10-27 06:28:00', '2135-10-27 10:28:00',
#                '2135-10-27 14:28:00', '2135-10-27 18:28:00',
#                '2135-10-27 22:28:00', '2135-10-28 02:28:00',
#                '2135-10-28 06:28:00', '2135-10-28 10:28:00',
#                '2135-10-28 14:28:00', '2135-10-28 18:28:00',
#                '2135-10-28 22:28:00', '2135-10-29 02:28:00',
#                '2135-10-29 06:28:00'],
#               dtype='datetime64[ns]', freq='4H')

# %%
cohort_df. \
        groupby(['subject_id', 'window_start', 'window_end']). \
        agg({'window_start' : lambda x: pd.date_range(start = x, periods = 18, freq = '4H')})
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby.py in agg_series(self, obj, func)
#    2264         try:
# -> 2265             return self._aggregate_series_fast(obj, func)
#    2266         except Exception:
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby.py in _aggregate_series_fast(self, obj, func)
#    2284                                     dummy)
# -> 2285         result, counts = grouper.get_result()
#    2286         return result, counts
#
# pandas/_libs/src/reduce.pyx in pandas._libs.lib.SeriesGrouper.get_result()
#
# pandas/_libs/src/reduce.pyx in pandas._libs.lib.SeriesGrouper.get_result()
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby.py in <lambda>(x)
#     846         func = self._is_builtin_func(func)
# --> 847         f = lambda x: func(x, *args, **kwargs)
#     848
#
# <ipython-input-74-ea68e3e99052> in <lambda>(x)
# ----> 1 cohort_df.         groupby(['subject_id', 'window_start', 'window_end']).         agg({'window_start' : lambda x: pd.date_range(start = x.values[1], periods = 18, freq = '4H')})
#
# IndexError: index 1 is out of bounds for axis 0 with size 1
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-74-ea68e3e99052> in <module>()
# ----> 1 cohort_df.         groupby(['subject_id', 'window_start', 'window_end']).         agg({'window_start' : lambda x: pd.date_range(start = x.values[1], periods = 18, freq = '4H')})
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    4187         versionadded=''))
#    4188     def aggregate(self, arg, *args, **kwargs):
# -> 4189         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    4190
#    4191     agg = aggregate
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby.py in aggregate(self, arg, *args, **kwargs)
#    3620
#    3621         _level = kwargs.pop('_level', None)
# -> 3622         result, how = self._aggregate(arg, _level=_level, *args, **kwargs)
#    3623         if how is None:
#    3624             return result
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/base.py in _aggregate(self, arg, *args, **kwargs)
#     476
#     477                 try:
# --> 478                     result = _agg(arg, _agg_1dim)
#     479                 except SpecificationError:
#     480
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/base.py in _agg(arg, func)
#     427                 result = compat.OrderedDict()
#     428                 for fname, agg_how in compat.iteritems(arg):
# --> 429                     result[fname] = func(fname, agg_how)
#     430                 return result
#     431
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/base.py in _agg_1dim(name, how, subset)
#     410                     raise SpecificationError("nested dictionary is ambiguous "
#     411                                              "in aggregation")
# --> 412                 return colg.aggregate(how, _level=(_level or 0) + 1)
#     413
#     414             def _agg_2dim(name, how):
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby.py in aggregate(self, func_or_funcs, *args, **kwargs)
#    3030
#    3031             if self.grouper.nkeys > 1:
# -> 3032                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#    3033
#    3034             try:
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     851         for name, obj in self._iterate_slices():
#     852             try:
# --> 853                 result, counts = self.grouper.agg_series(obj, f)
#     854                 output[name] = self._try_cast(result, obj, numeric_only=True)
#     855             except TypeError:
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby.py in agg_series(self, obj, func)
#    2265             return self._aggregate_series_fast(obj, func)
#    2266         except Exception:
# -> 2267             return self._aggregate_series_pure_python(obj, func)
#    2268
#    2269     def _aggregate_series_fast(self, obj, func):
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby.py in _aggregate_series_pure_python(self, obj, func)
#    2296
#    2297         for label, group in splitter:
# -> 2298             res = func(group)
#    2299             if result is None:
#    2300                 if (isinstance(res, (Series, Index, np.ndarray)) or
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/core/groupby.py in <lambda>(x)
#     845     def _python_agg_general(self, func, *args, **kwargs):
#     846         func = self._is_builtin_func(func)
# --> 847         f = lambda x: func(x, *args, **kwargs)
#     848
#     849         # iterate through "columns" ex exclusions to populate output dict
#
# <ipython-input-74-ea68e3e99052> in <lambda>(x)
# ----> 1 cohort_df.         groupby(['subject_id', 'window_start', 'window_end']).         agg({'window_start' : lambda x: pd.date_range(start = x.values[1], periods = 18, freq = '4H')})
#
# IndexError: index 1 is out of bounds for axis 0 with size 1

# %%
pd.to_datetime(cohort_df['suspected_infection_time_poe'].values)[1] + pd.DateOffset(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-46c95a03ca26> in <module>()
# ----> 1 cohort_df['suspected_infection_time_poe'].values[1] + pd.DateOffset(2)
#
# TypeError: ufunc add cannot use operands with types dtype('<M8[ns]') and dtype('O')
